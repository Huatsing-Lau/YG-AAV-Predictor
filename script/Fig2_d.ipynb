# %%
import pandas as pd
from plot_utils import plot_scatter

# %%
df = pd.read_csv('../figure_data/Fig2_d.csv')
plot_scatter(df, 'Log2 (Validated Score)', 'Log2 (AI Score)')
# Out:
# MSE: 0.6032952602953939
# RMSE: 0.7767208380720797
# MAE: 0.5996036828375906
# R-squared: 0.8299488917265679
