# %%
import pandas as pd
from plot_utils import plot_scatter

# %%
df = pd.read_csv('../figure_data/Fig2_b.csv')
plot_scatter(df, 'Log2 (Validated Score)', 'Log2 (AI Score)')
# Out:
# MSE: 0.7456950645920786
# RMSE: 0.8635363713197485
# MAE: 0.6576878686551191
# R-squared: 0.7674418229471072
