# %%
import pandas as pd
from plot_utils import plot_scatter

# %%
df = pd.read_csv('../figure_data/Fig2_f.csv')
plot_scatter(df, 'Log2 (Validated Score)', 'Log2 (AI Score)')
# Out:
# MSE: 0.09303750492856339
# RMSE: 0.30502049919401053
# MAE: 0.21988612883481903
# R-squared: 0.8930144495061634
